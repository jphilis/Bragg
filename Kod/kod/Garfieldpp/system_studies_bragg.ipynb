# %%
import matplotlib.pyplot as plt
import numpy as np
import sys, os
root_path = '/chalmers/sw/unsup64/root-6.26.10/lib'
sys.path.append(root_path)
from simple_bragg import Chamber
from bragg import BraggChamber
from func_lib import load_root_libraries, load_garfield, plot_chambers

# Suppress all text output
sys.stdout = open(os.devnull, 'w')
sys.stderr = open(os.devnull, 'w')

load_root_libraries()
load_garfield()

# %% [markdown]
# ## Rotate propagation of isotope

# %%
chamber1 = Chamber(
    "../DataFiles/EXYZ_He4-5.4MeV_2023-04-03_1113.txt",
    dx=1, 
    dy=0,
    label="(a) Signaler med parallell respektive"
    )

chamber2 = Chamber(
    "../DataFiles/EXYZ_He4-5.4MeV_2023-04-03_1113.txt",
    dx=0, 
    dy=1,
    label= "(b) vinkelrät stråle mot elektroder"
)
plot_chambers(chamber1, chamber2)
# Out:
# Welcome to JupyROOT 6.26/10

# %% [markdown]
# Anode, Cathode and Frisch

# %%
chamber = BraggChamber(
    "../DataFiles/EXYZ_He4-5.4MeV_2023-04-03_1113.txt",
    dx=0, 
    dy=1
)
plot_chambers(chamber)
